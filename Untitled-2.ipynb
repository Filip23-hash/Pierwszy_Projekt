# %%
message_1 = "I love programming in Python!"

# %%
message_2 = "Python is fun to learn."

# %%
print(message_1 + "  "  + message_2)
# Out:
# I love programming in Python!  Python is fun to learn.

# %%
f'{message_1} abc {message_2}'
# Out:
# 'I love programming in Python! abc Python is fun to learn.'

# %%
countries = ["USA", "Canada", "Germany", "France", "Australia"]

# %%
countries
# Out:
# ['USA', 'Canada', 'Germany', 'France', 'Australia']

# %%
print(countries[0])  # Output: USA
print(countries[1])  # Output: Canada
print(countries[2])  # Output: Germany
# Out:
# USA
# Canada
# Germany

# %%
countries[-1]
# Out:
# 'Australia'

# %%
#slicing example 
print(countries[0:3])  # Output: ['USA', 'Canada', 'Germany']
# Out:
# ['USA', 'Canada', 'Germany']

# %%
print(countries[0:4])  # Output: ['USA', 'Canada', 'Germany', 'France']
# Out:
# ['USA', 'Canada', 'Germany', 'France']

# %% [markdown]
# # Adding elements to a list

# %%
countries
# Out:
# ['USA', 'Canada', 'Germany', 'France', 'Australia']

# %%
countries.append("Ireland")

# %%
countries.insert(2, "Spain")

# %%
countries
# Out:
# ['USA', 'Canada', 'Spain', 'Germany', 'France', 'Australia', 'Ireland']

# %%
countries_2 = ["Italy", "Brazil"]

# %%
countries + countries_2
# Out:
# ['USA',
#  'Canada',
#  'Spain',
#  'Germany',
#  'France',
#  'Australia',
#  'Ireland',
#  'Italy',
#  'Brazil']

# %%
nested_countries = [countries, countries_2]

# %%
nested_countries
# Out:
# [['USA', 'Canada', 'Spain', 'Germany', 'France', 'Australia', 'Ireland'],
#  ['Italy', 'Brazil']]

# %% [markdown]
# # Removing elements

# %%
countries
# Out:
# ['USA', 'Canada', 'Spain', 'Germany', 'France', 'Australia', 'Ireland']

# %%
countries.remove("Germany")

# %%
countries
# Out:
# ['USA', 'Canada', 'Spain', 'France', 'Australia', 'Ireland']

# %%
countries.pop(-1)
# Out:
# 'Ireland'

# %%
del countries[1]

# %%
countries
# Out:
# ['USA', 'Spain', 'France', 'Australia']

# %% [markdown]
# # Sorting a list

# %%
numbers = [5, 2, 9, 1, 5, 6]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 5, 5, 6, 9]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [9, 6, 5, 5, 2, 1]

# %% [markdown]
# # Update an element

# %%
numbers[1] = 1000
numbers
# Out:
# [9, 1000, 5, 5, 2, 1]

# %%
countries[:]
# Out:
# ['USA', 'Spain', 'France', 'Australia']

# %%
new_list = countries[:]

# %%
countries.copy()
# Out:
# ['USA', 'Spain', 'France', 'Australia']

# %% [markdown]
# # Dictionary

# %%
for country in countries:
    print(country)
# Out:
# USA
# Spain
# France
# Australia

# %%
my_dict = {key1: "value1", key2: "value2", key3: "value3"}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[189], line 1
# ----> 1 my_dict = {key1: "value1", key2: "value2", key3: "value3"}
#
# NameError: name 'key1' is not defined

# %%
my_data = {"name": "Alice", "age": 30, "city": "New York"}

# %%
print(my_data)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York')])

# %%
my_data['height'] = 179

# %%
my_data
# Out:
# {'name': 'Alice', 'age': 31, 'city': 'Los Angeles', 'height': 179}

# %%
my_data.update({"age": 31, "city": "Los Angeles"})

# %%
my_data
# Out:
# {'name': 'Alice', 'age': 31, 'city': 'Los Angeles', 'height': 179}

# %% [markdown]
# # Copy a dictionary

# %%
new_dict = my_data.copy()

# %%
new_dict
# Out:
# {'name': 'Alice', 'age': 31, 'city': 'Los Angeles', 'height': 179}

# %% [markdown]
# # If statement

# %%
if "age" in my_data:
    print("Age is present in the dictionary.")
# Out:
# Age is present in the dictionary.

# %%
age = 18

if age >= 18:
    print("You are an adult.")

elif age>=13:
    print("You are a teenager.")

else:
    print("You are a kido.")
# Out:
# You are an adult.

# %% [markdown]
# # For loop
